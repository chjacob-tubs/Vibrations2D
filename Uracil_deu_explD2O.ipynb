# %% [markdown]
# # 2D IR Spectra

# %%
import Irspec2d
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
mol = 'molname' # used to name the plots

#path = 'data/uracil_undeu_explH2O/'
path = 'data/uracil_deu_explD2O/'
intmat = np.loadtxt('%s/intenmat.txt' %(path))
freqmat = np.loadtxt('%s/freqsmat.txt' %(path))


newmin = 1500
newmax = 2000
steps = 500

harm = None
if os.path.isfile('%s/intenmatharm.txt' %(path)) and os.path.isfile('%s/freqsmatharm.txt' %(path)):
    harm = True                 
    
    intmath = np.loadtxt('%s/intenmatharm.txt' %(path))
    freqmath = np.loadtxt('%s/freqsmatharm.txt' %(path))

# %%
anharmcalc = Irspec2d.Calc2dir.calc2dir(freqmat,intmat,verbose=True)
exc_x, exc_y, exc_i, emi_x, emi_y, emi_i, ble_x, ble_y, ble_i = anharmcalc.calc_all_2d_process()
spec = Irspec2d.Spectrum.spectrum(freqmat,intmat)

x,y,z = spec.calc_lorentz_spectrum2d(newmin,newmax,steps)
z_val = spec.find_minmax(z)

#harm = None
if harm:
    print()
    harmcalc = Irspec2d.Calc2dir.calc2dir(freqmath,intmath,verbose=True)
    exc_xh, exc_yh, exc_ih, emi_xh, emi_yh, emi_ih, ble_xh, ble_yh, ble_ih = harmcalc.calc_all_2d_process()
    spech = Irspec2d.Spectrum.spectrum(freqmath,intmath)

    xh,yh,zh = spech.calc_lorentz_spectrum2d(newmin,newmax,steps)
    z_valh = spech.find_minmax(zh)
# Out:
# Excitation from energy level 1 to 2 at ( 1671.3502786944646 , 49.46268095828236 ) rcm and intensity:  0.010595588385225342
# Excitation from energy level 1 to 3 at ( 1671.3502786944646 , 82.70361983185194 ) rcm and intensity:  0.06689057618506317
# Excitation from energy level 1 to 4 at ( 1671.3502786944646 , 1670.5308868192633 ) rcm and intensity:  16.879844135016096
# Excitation from energy level 1 to 5 at ( 1671.3502786944646 , 1717.6235383630392 ) rcm and intensity:  910.4766516530938
# Excitation from energy level 1 to 6 at ( 1671.3502786944646 , 1752.235735947641 ) rcm and intensity:  417.4043048756809
# Excitation from energy level 1 to 7 at ( 1671.3502786944646 , 1767.1103550096886 ) rcm and intensity:  2.6471658366170487
# Excitation from energy level 1 to 8 at ( 1671.3502786944646 , 1800.8637019698854 ) rcm and intensity:  0.31990809413034405
# Excitation from energy level 1 to 9 at ( 1671.3502786944646 , 1832.1477519650007 ) rcm and intensity:  0.2956461949236346
# Excitation from energy level 2 to 3 at ( 1720.812959652747 , 33.240938873569576 ) rcm and intensity:  0.08248619969981186
# Excitation from energy level 2 to 4 at ( 1720.812959652747 , 1621.068205860981 ) rcm and intensity:  0.2967459744139477
# Excitation from energy level 2 to 5 at ( 1720.812959652747 , 1668.1608574047568 ) rcm and intensity:  17.544276716383845
# Excitation from energy level 2 to 6 at ( 1720.812959652747 , 1702.7730549893586 ) rcm and intensity:  14.059218370375062
# Excitation from energy level 2 to 7 at ( 1720.812959652747 , 1717.6476740514063 ) rcm and intensity:  1778.7157415116899
# Excitation from energy level 2 to 8 at ( 1720.812959652747 , 1751.401021011603 ) rcm and intensity:  462.32738690781474
# Excitation from energy level 2 to 9 at ( 1720.812959652747 , 1782.6850710067183 ) rcm and intensity:  1.57031985387261
# Excitation from energy level 3 to 4 at ( 1754.0538985263165 , 1587.8272669874113 ) rcm and intensity:  0.0590733408148185
# Excitation from energy level 3 to 5 at ( 1754.0538985263165 , 1634.9199185311872 ) rcm and intensity:  0.4167618875977958
# Excitation from energy level 3 to 6 at ( 1754.0538985263165 , 1669.532116115789 ) rcm and intensity:  15.696582174566391
# Excitation from energy level 3 to 7 at ( 1754.0538985263165 , 1684.4067351778367 ) rcm and intensity:  1.6488976789748846
# Excitation from energy level 3 to 8 at ( 1754.0538985263165 , 1718.1600821380334 ) rcm and intensity:  960.7550063951069
# Excitation from energy level 3 to 9 at ( 1754.0538985263165 , 1749.4441321331487 ) rcm and intensity:  747.8311707262048
# Stimulated emission from energy level 1 to 0 at ( 1671.3502786944646 , 1671.3502786944646 ) rcm and intensity:  8.8454123332069
# Stimulated emission from energy level 2 to 0 at ( 1720.812959652747 , 1720.812959652747 ) rcm and intensity:  941.1945454529288
# Stimulated emission from energy level 3 to 0 at ( 1754.0538985263165 , 1754.0538985263165 ) rcm and intensity:  398.0932536193528
# Bleaching from energy level 0 to 1 at ( 1671.3502786944646 , 1671.3502786944646 ) rcm and intensity:  8.8454123332069
# Bleaching from energy level 0 to 1 at ( 1720.812959652747 , 1671.3502786944646 ) rcm and intensity:  8.8454123332069
# Bleaching from energy level 0 to 1 at ( 1754.0538985263165 , 1671.3502786944646 ) rcm and intensity:  8.8454123332069
# Bleaching from energy level 0 to 2 at ( 1671.3502786944646 , 1720.812959652747 ) rcm and intensity:  941.1945454529288
# Bleaching from energy level 0 to 2 at ( 1720.812959652747 , 1720.812959652747 ) rcm and intensity:  941.1945454529288
# Bleaching from energy level 0 to 2 at ( 1754.0538985263165 , 1720.812959652747 ) rcm and intensity:  941.1945454529288
# Bleaching from energy level 0 to 3 at ( 1671.3502786944646 , 1754.0538985263165 ) rcm and intensity:  398.0932536193528
# Bleaching from energy level 0 to 3 at ( 1720.812959652747 , 1754.0538985263165 ) rcm and intensity:  398.0932536193528
# Bleaching from energy level 0 to 3 at ( 1754.0538985263165 , 1754.0538985263165 ) rcm and intensity:  398.0932536193528
#
# Excitation from energy level 1 to 2 at ( 1664.5824370781024 , 44.20395941420793 ) rcm and intensity:  8.139901014459694e-30
# Excitation from energy level 1 to 3 at ( 1664.5824370781024 , 75.98475616528413 ) rcm and intensity:  4.420071259225961e-29
# Excitation from energy level 1 to 4 at ( 1664.5824370781024 , 1664.0998226001739 ) rcm and intensity:  30.4926738372357
# Excitation from energy level 1 to 5 at ( 1664.5824370781024 , 1708.4332660923474 ) rcm and intensity:  960.2505587525308
# Excitation from energy level 1 to 6 at ( 1664.5824370781024 , 1740.3619587717376 ) rcm and intensity:  394.39001894053365
# Excitation from energy level 1 to 7 at ( 1664.5824370781024 , 1752.5636615344247 ) rcm and intensity:  0.007438797940097288
# Excitation from energy level 1 to 8 at ( 1664.5824370781024 , 1784.4077589825602 ) rcm and intensity:  0.002221932593395958
# Excitation from energy level 1 to 9 at ( 1664.5824370781024 , 1816.0320609343844 ) rcm and intensity:  0.0023560550067636965
# Excitation from energy level 2 to 3 at ( 1708.7863964923104 , 31.780796751076196 ) rcm and intensity:  7.039334188845033e-29
# Excitation from energy level 2 to 4 at ( 1708.7863964923104 , 1619.895863185966 ) rcm and intensity:  0.002435910086864708
# Excitation from energy level 2 to 5 at ( 1708.7863964923104 , 1664.2293066781394 ) rcm and intensity:  15.737158310337044
# Excitation from energy level 2 to 6 at ( 1708.7863964923104 , 1696.1579993575297 ) rcm and intensity:  0.055298676065488224
# Excitation from energy level 2 to 7 at ( 1708.7863964923104 , 1708.3597021202168 ) rcm and intensity:  1919.8393182578463
# Excitation from energy level 2 to 8 at ( 1708.7863964923104 , 1740.2037995683522 ) rcm and intensity:  395.8771284142162
# Excitation from energy level 2 to 9 at ( 1708.7863964923104 , 1771.8281015201765 ) rcm and intensity:  0.014995340838589942
# Excitation from energy level 3 to 4 at ( 1740.5671932433866 , 1588.1150664348897 ) rcm and intensity:  0.0037288485244649614
# Excitation from energy level 3 to 5 at ( 1740.5671932433866 , 1632.4485099270632 ) rcm and intensity:  0.010791665097411716
# Excitation from energy level 3 to 6 at ( 1740.5671932433866 , 1664.3772026064535 ) rcm and intensity:  16.469631216286565
# Excitation from energy level 3 to 7 at ( 1740.5671932433866 , 1676.5789053691406 ) rcm and intensity:  0.009831250298436116
# Excitation from energy level 3 to 8 at ( 1740.5671932433866 , 1708.423002817276 ) rcm and intensity:  965.0797547482118
# Excitation from energy level 3 to 9 at ( 1740.5671932433866 , 1740.0473047691003 ) rcm and intensity:  782.5934381171944
# Stimulated emission from energy level 1 to 0 at ( 1664.5824370781024 , 1664.5824370781024 ) rcm and intensity:  17.1437500694236
# Stimulated emission from energy level 2 to 0 at ( 1708.7863964923104 , 1708.7863964923104 ) rcm and intensity:  960.914728461043
# Stimulated emission from energy level 3 to 0 at ( 1740.5671932433866 , 1740.5671932433866 ) rcm and intensity:  392.6989820776294
# Bleaching from energy level 0 to 1 at ( 1664.5824370781024 , 1664.5824370781024 ) rcm and intensity:  17.1437500694236
# Bleaching from energy level 0 to 1 at ( 1708.7863964923104 , 1664.5824370781024 ) rcm and intensity:  17.1437500694236
# Bleaching from energy level 0 to 1 at ( 1740.5671932433866 , 1664.5824370781024 ) rcm and intensity:  17.1437500694236
# Bleaching from energy level 0 to 2 at ( 1664.5824370781024 , 1708.7863964923104 ) rcm and intensity:  960.914728461043
# Bleaching from energy level 0 to 2 at ( 1708.7863964923104 , 1708.7863964923104 ) rcm and intensity:  960.914728461043
# Bleaching from energy level 0 to 2 at ( 1740.5671932433866 , 1708.7863964923104 ) rcm and intensity:  960.914728461043
# Bleaching from energy level 0 to 3 at ( 1664.5824370781024 , 1740.5671932433866 ) rcm and intensity:  392.6989820776294
# Bleaching from energy level 0 to 3 at ( 1708.7863964923104 , 1740.5671932433866 ) rcm and intensity:  392.6989820776294
# Bleaching from energy level 0 to 3 at ( 1740.5671932433866 , 1740.5671932433866 ) rcm and intensity:  392.6989820776294

# %%
spec.plot_2dspectrum_dots(newmin,newmax,ble_x,ble_y,ble_i,exc_x,exc_y,exc_i,emi_x,emi_y,emi_i)
#plt.savefig('%s_anharm.png' %(mol),bbox_inches='tight')

if harm:
    spec.plot_2dspectrum_dots(newmin,newmax,ble_xh,ble_yh,ble_ih,exc_xh,exc_yh,exc_ih,emi_xh,emi_yh,emi_ih)
    #plt.savefig('%s_harm.png' %(mol),bbox_inches='tight')

# %% [markdown]
# ### Plot 2D spectrum

# %%
fig, ax = plt.subplots(dpi=600)
plt.plot([0,newmax], [0,newmax], ls="--", c="0.75", linewidth=1)

plt.grid(True)
ax.set_aspect(1./ax.get_data_ratio())

fig = plt.contourf(x,y,z, 500, alpha=1, cmap=plt.cm.seismic, vmax=z_val, vmin=-z_val)
CS = plt.contour(x,y,z,25,colors='k',linewidths=.25)

cbar = plt.colorbar(fig)
cbar.ax.tick_params(labelsize=12)
ax.tick_params(labelsize=12)
plt.xlabel('Pump', fontsize=18)
plt.ylabel('Probe', fontsize=18)
plt.xlim(newmin,newmax)
plt.ylim(newmin,newmax)

plt.plot(ble_x,ble_y, "x", color='gold', label='bleaching', markersize=10)
plt.plot(exc_x,exc_y, "bx", label='excitation', markersize=5)
plt.plot(emi_x,emi_y, "gx", label='stim. emiss.', markersize=5)


#plt.savefig('%s_anharm_lorentz.png' %(mol),bbox_inches='tight')

# %%
if harm:
    fig, ax = plt.subplots(dpi=600)
    plt.plot([0,newmax], [0,newmax], ls="--", c="0.75", linewidth=1)

    plt.grid(True)
    ax.set_aspect(1./ax.get_data_ratio())

    fig = plt.contourf(xh,yh,zh, 500, alpha=1, cmap=plt.cm.seismic, vmax=z_val, vmin=-z_val)
    CS = plt.contour(xh,yh,zh,25,colors='k',linewidths=.25)

    cbar = plt.colorbar(fig)
    cbar.ax.tick_params(labelsize=12)
    ax.tick_params(labelsize=12)
    plt.xlabel('Pump', fontsize=18)
    plt.ylabel('Probe', fontsize=18)
    plt.xlim(newmin,newmax)
    plt.ylim(newmin,newmax)

    plt.plot(ble_xh,ble_yh, "x", color='gold', label='bleaching', markersize=10)
    plt.plot(exc_xh,exc_yh, "bx", label='excitation', markersize=5)
    plt.plot(emi_xh,emi_yh, "gx", label='stim. emiss.', markersize=5)


    #plt.savefig('%s_harm_lorentz.png' %(mol),bbox_inches='tight')
